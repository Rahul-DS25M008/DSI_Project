# %% [markdown]
# ### Lets start the cleaning process by importing the necessary libraries and setting some default visual parameters for better viewing

# %%
import pandas as pd
import numpy as np
from urllib.parse import urlparse
import os
from pathlib import Path
import re
import ast
import json

pd.set_option("display.max_rows", 20)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 140)

# %%
# path to the raw failory CSV
file_path = "/workspaces/dsi-ws2025-project-grpab-weigl-mds1ab-awp-proj2/Data_Acquisition/failory_eu_companies_raw.csv"  

df = pd.read_csv(file_path, dtype=str).fillna("")
print("Loaded shape:", df.shape)
df.head(5)
# Out:
# Loaded shape: (5103, 15)
#   rank  country       name                                        description           state      city started_in  \
# 0    1  Austria   Bitpanda  Bitpanda is a digital asset exchange that make...            Wien    Vienna       2014
# 1    2  Austria   Tractive  Tractive is a company that creates GPS trackin...  Oberosterreich  Pasching       2012
# 2    3  Austria  GoStudent  In a virtual learning environment, GoStudent i...            Wien    Vienna       2016
# 3    4  Austria    Allcyte  Allcyte is a biotech start-up focused on patie...            Wien    Vienna       2017
# 4    5  Austria   Adverity  Adverity is a data-driven marketing analytics ...            Wien    Vienna       2015
#
#                                             founders                                         industries employees   funding_raw  \
# 0     Christian Trummer, Eric Demuth, Paul Klanschek       Bitcoin, Blockchain, Cryptocurrency, FinTech   251-500  $283,013,472
# 1  Michael Hurnaus, Michael Lettner, Michael Tsch...                      GPS, Pet, Software, Wearables    51-100   $37,687,997
# 2      Felix Ohswald, Gregor MÃ¼ller, Moritz Ohswald      Apps, Continuing Education, EdTech, Education   251-500  $100,662,844
# 3  Berend Snijder, Giulio Superti-Furga, Gregory ...  Biotechnology, Health Diagnostics, Machine Lea...     11-50    $6,000,000
# 4  Alexander IgelsbÃ¶ck, Andreas GlÃ¤nzer, Martin...  Advertising, Analytics, Artificial Intelligenc...   101-250   $46,298,685
#
#   funding_rounds investors_count                                     investors_list                                source_url
# 0              5               6  ['DST Global', 'Wintermute Trading', 'Speedinv...  https://www.failory.com/startups/austria
# 1              5               5  ['Guidepost Growth Equity', 'Monkfish Equity',...  https://www.failory.com/startups/austria
# 2              6               7  ['DN Capital', 'Coatue', 'Speedinvest', 'Left ...  https://www.failory.com/startups/austria
# 3              2               5  ['42CAP', 'Air Street Capital', 'PUSH Ventures...  https://www.failory.com/startups/austria
# 4              4               7  ['Sapphire Ventures', 'Speedinvest', 'Felix Ca...  https://www.failory.com/startups/austria

# %%
print("Columns:", df.columns.tolist())
print("\nDtypes:")
print(df.dtypes)

print("\nNull counts:")
print(df.isna().sum().sort_values(ascending=False))
# Out:
# Columns: ['rank', 'country', 'name', 'description', 'state', 'city', 'started_in', 'founders', 'industries', 'employees', 'funding_raw', 'funding_rounds', 'investors_count', 'investors_list', 'source_url']
#
# Dtypes:
# rank               object
# country            object
# name               object
# description        object
# state              object
# city               object
# started_in         object
# founders           object
# industries         object
# employees          object
# funding_raw        object
# funding_rounds     object
# investors_count    object
# investors_list     object
# source_url         object
# dtype: object
#
# Null counts:
# rank               0
# country            0
# name               0
# description        0
# state              0
# city               0
# started_in         0
# founders           0
# industries         0
# employees          0
# funding_raw        0
# funding_rounds     0
# investors_count    0
# investors_list     0
# source_url         0
# dtype: int64

# %% [markdown]
# Unlike our first source where the data was mostly missing for multiple features, we can see here that we have no nulls in this dataset and the quality of data is really good due to the source we picked (Focused on companies instead of a broad sourc elike wikidata)
#
# Though we only have 5k records, most of these records are rich in information and we can hopefully clean this up to make the data more standardized without losing any more information

# %% [markdown]
# In the next following steps, let us try to clean the most important columns one by one and try to standardize them into a unified format

# %%
df_fail = df.copy()   # Working on a copy of data before commiting to the main dataframe

# Converting the feature started_in to int
df_fail["started_in"] = pd.to_numeric(df_fail["started_in"], errors="coerce")

# Converting employees "251-500" → min/max numeric scale for consistency. We will drop the original column in the end
def parse_employees(x):
    if "-" in x:
        low, high = x.split("-")
        return int(low), int(high)
    # single number (rare)
    if x.isdigit():
        return int(x), int(x)
    return np.nan, np.nan

df_fail[["employees_min", "employees_max"]] = df_fail["employees"].apply(
    lambda x: pd.Series(parse_employees(x))
)

df_fail.head(5)
# Out:
#   rank  country       name                                        description           state      city  started_in  \
# 0    1  Austria   Bitpanda  Bitpanda is a digital asset exchange that make...            Wien    Vienna      2014.0
# 1    2  Austria   Tractive  Tractive is a company that creates GPS trackin...  Oberosterreich  Pasching      2012.0
# 2    3  Austria  GoStudent  In a virtual learning environment, GoStudent i...            Wien    Vienna      2016.0
# 3    4  Austria    Allcyte  Allcyte is a biotech start-up focused on patie...            Wien    Vienna      2017.0
# 4    5  Austria   Adverity  Adverity is a data-driven marketing analytics ...            Wien    Vienna      2015.0
#
#                                             founders                                         industries employees   funding_raw  \
# 0     Christian Trummer, Eric Demuth, Paul Klanschek       Bitcoin, Blockchain, Cryptocurrency, FinTech   251-500  $283,013,472
# 1  Michael Hurnaus, Michael Lettner, Michael Tsch...                      GPS, Pet, Software, Wearables    51-100   $37,687,997
# 2      Felix Ohswald, Gregor MÃ¼ller, Moritz Ohswald      Apps, Continuing Education, EdTech, Education   251-500  $100,662,844
# 3  Berend Snijder, Giulio Superti-Furga, Gregory ...  Biotechnology, Health Diagnostics, Machine Lea...     11-50    $6,000,000
# 4  Alexander IgelsbÃ¶ck, Andreas GlÃ¤nzer, Martin...  Advertising, Analytics, Artificial Intelligenc...   101-250   $46,298,685
#
#   funding_rounds investors_count                                     investors_list                                source_url  \
# 0              5               6  ['DST Global', 'Wintermute Trading', 'Speedinv...  https://www.failory.com/startups/austria
# 1              5               5  ['Guidepost Growth Equity', 'Monkfish Equity',...  https://www.failory.com/startups/austria
# 2              6               7  ['DN Capital', 'Coatue', 'Speedinvest', 'Left ...  https://www.failory.com/startups/austria
# 3              2               5  ['42CAP', 'Air Street Capital', 'PUSH Ventures...  https://www.failory.com/startups/austria
# 4              4               7  ['Sapphire Ventures', 'Speedinvest', 'Felix Ca...  https://www.failory.com/startups/austria
#
#    employees_min  employees_max
# 0          251.0          500.0
# 1           51.0          100.0
# 2          251.0          500.0
# 3           11.0           50.0
# 4          101.0          250.0

# %%
# Converting funding_raw values like "$283,013,472" → numeric
def parse_funding(amount):
    if amount in [None, '']:
        return np.nan
    cleaned = amount.replace("$", "").replace(",", "")
    if cleaned.lower().endswith("k"):
        return float(cleaned[:-1]) * 1_000
    if cleaned.lower().endswith("m"):
        return float(cleaned[:-1]) * 1_000_000
    if cleaned.lower().endswith("b"):
        return float(cleaned[:-1]) * 1_000_000_000
    return float(cleaned)

df_fail["funding_usd"] = df_fail["funding_raw"].apply(parse_funding)
df_fail.head()
# Out:
#   rank  country       name                                        description           state      city  started_in  \
# 0    1  Austria   Bitpanda  Bitpanda is a digital asset exchange that make...            Wien    Vienna      2014.0
# 1    2  Austria   Tractive  Tractive is a company that creates GPS trackin...  Oberosterreich  Pasching      2012.0
# 2    3  Austria  GoStudent  In a virtual learning environment, GoStudent i...            Wien    Vienna      2016.0
# 3    4  Austria    Allcyte  Allcyte is a biotech start-up focused on patie...            Wien    Vienna      2017.0
# 4    5  Austria   Adverity  Adverity is a data-driven marketing analytics ...            Wien    Vienna      2015.0
#
#                                             founders                                         industries employees   funding_raw  \
# 0     Christian Trummer, Eric Demuth, Paul Klanschek       Bitcoin, Blockchain, Cryptocurrency, FinTech   251-500  $283,013,472
# 1  Michael Hurnaus, Michael Lettner, Michael Tsch...                      GPS, Pet, Software, Wearables    51-100   $37,687,997
# 2      Felix Ohswald, Gregor MÃ¼ller, Moritz Ohswald      Apps, Continuing Education, EdTech, Education   251-500  $100,662,844
# 3  Berend Snijder, Giulio Superti-Furga, Gregory ...  Biotechnology, Health Diagnostics, Machine Lea...     11-50    $6,000,000
# 4  Alexander IgelsbÃ¶ck, Andreas GlÃ¤nzer, Martin...  Advertising, Analytics, Artificial Intelligenc...   101-250   $46,298,685
#
#   funding_rounds investors_count                                     investors_list                                source_url  \
# 0              5               6  ['DST Global', 'Wintermute Trading', 'Speedinv...  https://www.failory.com/startups/austria
# 1              5               5  ['Guidepost Growth Equity', 'Monkfish Equity',...  https://www.failory.com/startups/austria
# 2              6               7  ['DN Capital', 'Coatue', 'Speedinvest', 'Left ...  https://www.failory.com/startups/austria
# 3              2               5  ['42CAP', 'Air Street Capital', 'PUSH Ventures...  https://www.failory.com/startups/austria
# 4              4               7  ['Sapphire Ventures', 'Speedinvest', 'Felix Ca...  https://www.failory.com/startups/austria
#
#    employees_min  employees_max  funding_usd
# 0          251.0          500.0  283013472.0
# 1           51.0          100.0   37687997.0
# 2          251.0          500.0  100662844.0
# 3           11.0           50.0    6000000.0
# 4          101.0          250.0   46298685.0

# %%
#Converting investors_count & funding_rounds to int

df_fail["funding_rounds"] = pd.to_numeric(df_fail["funding_rounds"], errors="coerce", downcast="integer")
df_fail["investors_count"] = pd.to_numeric(df_fail["investors_count"], errors="coerce", downcast="integer")

# %%
#Converting investors_list string to a list
def parse_investor_list(x):
    if not isinstance(x, str) or x.strip() == "":
        return []
    s = x.strip()
    s = s.replace("'", '"')
    s = re.sub(r',$', '', s)  
    if not s.startswith("["):
        s = "[" + s
    if not s.endswith("]"):
        s = s + "]"
    try:
        return json.loads(s)
    except:
        return [item.strip() for item in re.split(r",\s*", x) if item.strip()]

df_fail["investors_list"] = df_fail["investors_list"].apply(parse_investor_list)


#Standardizing industries and founders into list
df_fail["industries_list"] = df_fail["industries"].apply(lambda x: [i.strip() for i in x.split(",")])
df_fail["founders_list"] = df_fail["founders"].apply(lambda x: [i.strip() for i in x.split(",")])

df_fail.head()
# Out:
#   rank  country       name                                        description           state      city  started_in  \
# 0    1  Austria   Bitpanda  Bitpanda is a digital asset exchange that make...            Wien    Vienna      2014.0
# 1    2  Austria   Tractive  Tractive is a company that creates GPS trackin...  Oberosterreich  Pasching      2012.0
# 2    3  Austria  GoStudent  In a virtual learning environment, GoStudent i...            Wien    Vienna      2016.0
# 3    4  Austria    Allcyte  Allcyte is a biotech start-up focused on patie...            Wien    Vienna      2017.0
# 4    5  Austria   Adverity  Adverity is a data-driven marketing analytics ...            Wien    Vienna      2015.0
#
#                                             founders                                         industries employees   funding_raw  \
# 0     Christian Trummer, Eric Demuth, Paul Klanschek       Bitcoin, Blockchain, Cryptocurrency, FinTech   251-500  $283,013,472
# 1  Michael Hurnaus, Michael Lettner, Michael Tsch...                      GPS, Pet, Software, Wearables    51-100   $37,687,997
# 2      Felix Ohswald, Gregor MÃ¼ller, Moritz Ohswald      Apps, Continuing Education, EdTech, Education   251-500  $100,662,844
# 3  Berend Snijder, Giulio Superti-Furga, Gregory ...  Biotechnology, Health Diagnostics, Machine Lea...     11-50    $6,000,000
# 4  Alexander IgelsbÃ¶ck, Andreas GlÃ¤nzer, Martin...  Advertising, Analytics, Artificial Intelligenc...   101-250   $46,298,685
#
#    funding_rounds  investors_count                                     investors_list                                source_url  \
# 0             5.0              6.0  [DST Global, Wintermute Trading, Speedinvest, ...  https://www.failory.com/startups/austria
# 1             5.0              5.0  [['Guidepost Growth Equity', 'Monkfish Equity'...  https://www.failory.com/startups/austria
# 2             6.0              7.0  [DN Capital, Coatue, Speedinvest, Left Lane Ca...  https://www.failory.com/startups/austria
# 3             2.0              5.0  [42CAP, Air Street Capital, PUSH Ventures, Ami...  https://www.failory.com/startups/austria
# 4             4.0              7.0  [Sapphire Ventures, Speedinvest, Felix Capital...  https://www.failory.com/startups/austria
#
#    employees_min  employees_max  funding_usd                                    industries_list  \
# 0          251.0          500.0  283013472.0     [Bitcoin, Blockchain, Cryptocurrency, FinTech]
# 1           51.0          100.0   37687997.0                    [GPS, Pet, Software, Wearables]
# 2          251.0          500.0  100662844.0    [Apps, Continuing Education, EdTech, Education]
# 3           11.0           50.0    6000000.0  [Biotechnology, Health Diagnostics, Machine Le...
# 4          101.0          250.0   46298685.0  [Advertising, Analytics, Artificial Intelligen...
#
#                                        founders_list
# 0   [Christian Trummer, Eric Demuth, Paul Klanschek]
# 1  [Michael Hurnaus, Michael Lettner, Michael Tsc...
# 2    [Felix Ohswald, Gregor MÃ¼ller, Moritz Ohswald]
# 3  [Berend Snijder, Giulio Superti-Furga, Gregory...
# 4  [Alexander IgelsbÃ¶ck, Andreas GlÃ¤nzer, Marti...

# %% [markdown]
# With this step, now we already have parsed employee ranges, funding converted to numeric which is a valuable feature, cleaned industry and founders list. So, we can now move on to the final cleaning steps

# %%
# Trimming whitespaces & unifying the casing of letters
text_cols = [
    "country", "name", "description", "state", "city",
    "founders", "industries"
]

for c in text_cols:
    df_fail[c] = df_fail[c].astype(str).str.strip()

# Standardizing country casing for consistency
df_fail["country"] = df_fail["country"].str.title()

# Normalizing city/state to title-case
df_fail["city"] = df_fail["city"].str.title()
df_fail["state"] = df_fail["state"].str.title()

df_fail.head(5)
# Out:
#   rank  country       name                                        description           state      city  started_in  \
# 0    1  Austria   Bitpanda  Bitpanda is a digital asset exchange that make...            Wien    Vienna      2014.0
# 1    2  Austria   Tractive  Tractive is a company that creates GPS trackin...  Oberosterreich  Pasching      2012.0
# 2    3  Austria  GoStudent  In a virtual learning environment, GoStudent i...            Wien    Vienna      2016.0
# 3    4  Austria    Allcyte  Allcyte is a biotech start-up focused on patie...            Wien    Vienna      2017.0
# 4    5  Austria   Adverity  Adverity is a data-driven marketing analytics ...            Wien    Vienna      2015.0
#
#                                             founders                                         industries employees   funding_raw  \
# 0     Christian Trummer, Eric Demuth, Paul Klanschek       Bitcoin, Blockchain, Cryptocurrency, FinTech   251-500  $283,013,472
# 1  Michael Hurnaus, Michael Lettner, Michael Tsch...                      GPS, Pet, Software, Wearables    51-100   $37,687,997
# 2      Felix Ohswald, Gregor MÃ¼ller, Moritz Ohswald      Apps, Continuing Education, EdTech, Education   251-500  $100,662,844
# 3  Berend Snijder, Giulio Superti-Furga, Gregory ...  Biotechnology, Health Diagnostics, Machine Lea...     11-50    $6,000,000
# 4  Alexander IgelsbÃ¶ck, Andreas GlÃ¤nzer, Martin...  Advertising, Analytics, Artificial Intelligenc...   101-250   $46,298,685
#
#    funding_rounds  investors_count                                     investors_list                                source_url  \
# 0             5.0              6.0  [DST Global, Wintermute Trading, Speedinvest, ...  https://www.failory.com/startups/austria
# 1             5.0              5.0  [['Guidepost Growth Equity', 'Monkfish Equity'...  https://www.failory.com/startups/austria
# 2             6.0              7.0  [DN Capital, Coatue, Speedinvest, Left Lane Ca...  https://www.failory.com/startups/austria
# 3             2.0              5.0  [42CAP, Air Street Capital, PUSH Ventures, Ami...  https://www.failory.com/startups/austria
# 4             4.0              7.0  [Sapphire Ventures, Speedinvest, Felix Capital...  https://www.failory.com/startups/austria
#
#    employees_min  employees_max  funding_usd                                    industries_list  \
# 0          251.0          500.0  283013472.0     [Bitcoin, Blockchain, Cryptocurrency, FinTech]
# 1           51.0          100.0   37687997.0                    [GPS, Pet, Software, Wearables]
# 2          251.0          500.0  100662844.0    [Apps, Continuing Education, EdTech, Education]
# 3           11.0           50.0    6000000.0  [Biotechnology, Health Diagnostics, Machine Le...
# 4          101.0          250.0   46298685.0  [Advertising, Analytics, Artificial Intelligen...
#
#                                        founders_list
# 0   [Christian Trummer, Eric Demuth, Paul Klanschek]
# 1  [Michael Hurnaus, Michael Lettner, Michael Tsc...
# 2    [Felix Ohswald, Gregor MÃ¼ller, Moritz Ohswald]
# 3  [Berend Snijder, Giulio Superti-Furga, Gregory...
# 4  [Alexander IgelsbÃ¶ck, Andreas GlÃ¤nzer, Marti...

# %% [markdown]
# We wrap up the basic standardization of textual columns with the code above as we can now move on to the numeric columns next

# %%
num_cols = ["started_in", "funding_rounds", "investors_count",
            "employees_min", "employees_max", "funding_usd"]

df_fail[num_cols] = df_fail[num_cols].apply(pd.to_numeric, errors="coerce")
df_fail[num_cols].describe()
# Out:
#         started_in  funding_rounds  investors_count  employees_min  employees_max   funding_usd
# count  1408.000000     1406.000000      1360.000000    4673.000000    4673.000000  3.295000e+03
# mean   2012.031960        3.886913         7.086765     195.304943     372.558956  4.759209e+07
# std      12.951211        2.324405         5.661520    2071.937509    2291.545119  2.346095e+08
# min    1836.000000        1.000000         1.000000       1.000000       8.000000  1.196000e+03
# 25%    2012.000000        2.000000         3.000000       1.000000      10.000000  6.623205e+05
# 50%    2014.000000        3.000000         6.000000      11.000000      50.000000  3.191836e+06
# 75%    2017.000000        5.000000         9.000000      51.000000     100.000000  1.970943e+07
# max    2022.000000       27.000000        56.000000   43840.000000   43840.000000  6.040093e+09

# %%
df_fail.isna().sum().sort_values(ascending=False)
# Out:
# investors_count    3743
# funding_rounds     3697
# started_in         3695
# funding_usd        1808
# employees_min       430
# employees_max       430
# country               0
# rank                  0
# description           0
# name                  0
# city                  0
# state                 0
# funding_raw           0
# employees             0
# industries            0
# founders              0
# source_url            0
# investors_list        0
# industries_list       0
# founders_list         0
# dtype: int64

# %% [markdown]
# As a final step, let us look at the nulls for each column and decide what to do with them

# %%
df_fail[df_fail['investors_count'].isnull()]
# Out:
#      rank         country                   name                                        description state       city  started_in founders  \
# 22     23         Austria          Ares-Genetics  Ares Genetics creates DNA-Sequencing Tests bas...           Vienna         NaN
# 23     24         Austria              journiApp  Using AI, you can make print items like photo ...           Vienna         NaN
# 24     25         Austria          DerBrutkasten  Der Brutkasten is a multimedia portal for star...           Vienna         NaN
# 25     26         Austria                 Kokoro  Kokoro captures the critical variables that le...           Vienna         NaN
# 26     27         Austria               seasonax  Financial professionals can use Seasonax, an a...           Vienna         NaN
# ...   ...             ...                    ...                                                ...   ...        ...         ...      ...
# 5098  296  United Kingdom  Abbey Logistics Group  Abbey Logistics Group is a more environmentall...        Liverpool         NaN
# 5099  297  United Kingdom                  Mando  Through the concept, Mando assists large organ...        Liverpool         NaN
# 5100  298  United Kingdom            Littlewoods  Littlewoods was a Liverpool-based retail and f...        Liverpool         NaN
# 5101  299  United Kingdom              Homelease  Homelease develops creative solutions to diffi...        Liverpool         NaN
# 5102  300  United Kingdom             The Reader  Our goal is to permanently alter how individua...        Liverpool         NaN
#
#      industries employees funding_raw  funding_rounds  investors_count investors_list                                       source_url  \
# 22                   1-10  $1,489,467             NaN              NaN             []         https://www.failory.com/startups/austria
# 23                   1-10    $452,207             NaN              NaN             []         https://www.failory.com/startups/austria
# 24                   1-10  $2,804,100             NaN              NaN             []         https://www.failory.com/startups/austria
# 25                   1-10    $315,357             NaN              NaN             []         https://www.failory.com/startups/austria
# 26                   1-10  $1,301,989             NaN              NaN             []         https://www.failory.com/startups/austria
# ...         ...       ...         ...             ...              ...            ...                                              ...
# 5098             501-1000                         NaN              NaN             []  https://www.failory.com/startups/united-kingdom
# 5099               10001+                         NaN              NaN             []  https://www.failory.com/startups/united-kingdom
# 5100                                              NaN              NaN             []  https://www.failory.com/startups/united-kingdom
# 5101                 1-10                         NaN              NaN             []  https://www.failory.com/startups/united-kingdom
# 5102                11-50                         NaN              NaN             []  https://www.failory.com/startups/united-kingdom
#
#       employees_min  employees_max  funding_usd industries_list founders_list
# 22              1.0           10.0    1489467.0              []            []
# 23              1.0           10.0     452207.0              []            []
# 24              1.0           10.0    2804100.0              []            []
# 25              1.0           10.0     315357.0              []            []
# 26              1.0           10.0    1301989.0              []            []
# ...             ...            ...          ...             ...           ...
# 5098          501.0         1000.0          NaN              []            []
# 5099            NaN            NaN          NaN              []            []
# 5100            NaN            NaN          NaN              []            []
# 5101            1.0           10.0          NaN              []            []
# 5102           11.0           50.0          NaN              []            []
#
# [3743 rows x 20 columns]

# %% [markdown]
# Although some of these columns have nulls for these fields, we still retai important information like the name, country, funding amount etc for these so it only makes sense to retain everything in the final dataset despite the nulls

# %%
# Fixing encoding issues
df_final = df_fail.copy()
df_final["description"] = df_final["description"].str.encode("latin1", errors="ignore").str.decode("utf-8", errors="ignore")
df_final["founders"] = df_final["founders"].str.encode("latin1", errors="ignore").str.decode("utf-8", errors="ignore")
df_final["name"] = df_final["name"].str.encode("latin1", errors="ignore").str.decode("utf-8", errors="ignore")

# Converting list fields to JSON strings for safe CSV export
list_cols = ["industries_list", "founders_list", "investors_list"]
for col in list_cols:
    df_final[col] = df_final[col].apply(json.dumps)

#Previewing the head of the final dataset
df_final.head(10)
# Out:
#   rank  country       name                                        description           state      city  started_in  \
# 0    1  Austria   Bitpanda  Bitpanda is a digital asset exchange that make...            Wien    Vienna      2014.0
# 1    2  Austria   Tractive  Tractive is a company that creates GPS trackin...  Oberosterreich  Pasching      2012.0
# 2    3  Austria  GoStudent  In a virtual learning environment, GoStudent i...            Wien    Vienna      2016.0
# 3    4  Austria    Allcyte  Allcyte is a biotech start-up focused on patie...            Wien    Vienna      2017.0
# 4    5  Austria   Adverity  Adverity is a data-driven marketing analytics ...            Wien    Vienna      2015.0
# 5    6  Austria  PlanRadar  PlanRadar is a SaaS service for construction a...            Wien    Vienna      2013.0
# 6    7  Austria   refurbed  Refurbed is an online marketplace for refurbis...            Wien    Vienna      2017.0
# 7    8  Austria  TourRadar  TourRadar is a website that allows you to comp...            Wien    Vienna      2010.0
# 8    9  Austria       byrd  byrd is a member of an international e-commerc...            Wien    Vienna      2016.0
# 9   10  Austria       Mimo  Mimo is a program that teaches computer scienc...            Wien    Vienna      2016.0
#
#                                             founders                                         industries employees   funding_raw  \
# 0     Christian Trummer, Eric Demuth, Paul Klanschek       Bitcoin, Blockchain, Cryptocurrency, FinTech   251-500  $283,013,472
# 1  Michael Hurnaus, Michael Lettner, Michael Tsch...                      GPS, Pet, Software, Wearables    51-100   $37,687,997
# 2       Felix Ohswald, Gregor Müller, Moritz Ohswald      Apps, Continuing Education, EdTech, Education   251-500  $100,662,844
# 3  Berend Snijder, Giulio Superti-Furga, Gregory ...  Biotechnology, Health Diagnostics, Machine Lea...     11-50    $6,000,000
# 4  Alexander Igelsböck, Andreas Glänzer, Martin B...  Advertising, Analytics, Artificial Intelligenc...   101-250   $46,298,685
# 5  Clemens Hammerl, Constantin Köck, Domagoj Doli...  Android, Architecture, Building Maintenance, C...   101-250
# 6  Jürgen Riedl, Kilian Kaminski, Peter Windischh...  Apps, E-Commerce, Electronics, Marketplace, So...    51-100   $19,239,651
# 7                      Shawn Pittman, Travis Pittman        Marketplace, Search Engine, Tourism, Travel   251-500   $66,500,000
# 8  Alexander Leichter, Christoph Krofitsch, Petra...     E-Commerce, Logistics, Supply Chain Management    51-100
# 9  Dennis Daume, Henry Ameseder, Johannes Berger,...    E-Learning, Information Technology, Mobile Apps     11-50      $650,000
#
#    funding_rounds  investors_count                                     investors_list                                source_url  \
# 0             5.0              6.0  ["DST Global", "Wintermute Trading", "Speedinv...  https://www.failory.com/startups/austria
# 1             5.0              5.0  ["['Guidepost Growth Equity'", "'Monkfish Equi...  https://www.failory.com/startups/austria
# 2             6.0              7.0  ["DN Capital", "Coatue", "Speedinvest", "Left ...  https://www.failory.com/startups/austria
# 3             2.0              5.0  ["42CAP", "Air Street Capital", "PUSH Ventures...  https://www.failory.com/startups/austria
# 4             4.0              7.0  ["Sapphire Ventures", "Speedinvest", "Felix Ca...  https://www.failory.com/startups/austria
# 5             4.0              6.0  ["Insight Partners", "Headline", "Cavalry Vent...  https://www.failory.com/startups/austria
# 6             3.0             10.0  ["FJ Labs", "Speedinvest", "All Iron Ventures"...  https://www.failory.com/startups/austria
# 7             5.0             14.0  ["TCV", "Speedinvest", "Cherry Ventures", "End...  https://www.failory.com/startups/austria
# 8             3.0              8.0  ["FJ Labs", "Speedinvest", "VentureFriends", "...  https://www.failory.com/startups/austria
# 9             2.0              8.0  ["['Techstars'", "'Techstars Berlin Accelerato...  https://www.failory.com/startups/austria
#
#    employees_min  employees_max  funding_usd                                    industries_list  \
# 0          251.0          500.0  283013472.0  ["Bitcoin", "Blockchain", "Cryptocurrency", "F...
# 1           51.0          100.0   37687997.0            ["GPS", "Pet", "Software", "Wearables"]
# 2          251.0          500.0  100662844.0  ["Apps", "Continuing Education", "EdTech", "Ed...
# 3           11.0           50.0    6000000.0  ["Biotechnology", "Health Diagnostics", "Machi...
# 4          101.0          250.0   46298685.0  ["Advertising", "Analytics", "Artificial Intel...
# 5          101.0          250.0          NaN  ["Android", "Architecture", "Building Maintena...
# 6           51.0          100.0   19239651.0  ["Apps", "E-Commerce", "Electronics", "Marketp...
# 7          251.0          500.0   66500000.0  ["Marketplace", "Search Engine", "Tourism", "T...
# 8           51.0          100.0          NaN  ["E-Commerce", "Logistics", "Supply Chain Mana...
# 9           11.0           50.0     650000.0  ["E-Learning", "Information Technology", "Mobi...
#
#                                        founders_list
# 0  ["Christian Trummer", "Eric Demuth", "Paul Kla...
# 1  ["Michael Hurnaus", "Michael Lettner", "Michae...
# 2  ["Felix Ohswald", "Gregor M\u00c3\u00bcller", ...
# 3  ["Berend Snijder", "Giulio Superti-Furga", "Gr...
# 4  ["Alexander Igelsb\u00c3\u00b6ck", "Andreas Gl...
# 5  ["Clemens Hammerl", "Constantin K\u00c3\u00b6c...
# 6  ["J\u00c3\u00bcrgen Riedl", "Kilian Kaminski",...
# 7                ["Shawn Pittman", "Travis Pittman"]
# 8  ["Alexander Leichter", "Christoph Krofitsch", ...
# 9  ["Dennis Daume", "Henry Ameseder", "Johannes B...

# %%
# Saving the cleaned file as a csv for further use and ending the notebook here
output_path = "failory_clean_eu_companies.csv"

df_final.to_csv(output_path, index=False, encoding="utf-8")

print(f"Exported cleaned dataset to: {output_path}")
print(df_final.shape)
df_final.head()
# Out:
# Exported cleaned dataset to: failory_clean_eu_companies.csv
# (5103, 20)
#   rank  country       name                                        description           state      city  started_in  \
# 0    1  Austria   Bitpanda  Bitpanda is a digital asset exchange that make...            Wien    Vienna      2014.0
# 1    2  Austria   Tractive  Tractive is a company that creates GPS trackin...  Oberosterreich  Pasching      2012.0
# 2    3  Austria  GoStudent  In a virtual learning environment, GoStudent i...            Wien    Vienna      2016.0
# 3    4  Austria    Allcyte  Allcyte is a biotech start-up focused on patie...            Wien    Vienna      2017.0
# 4    5  Austria   Adverity  Adverity is a data-driven marketing analytics ...            Wien    Vienna      2015.0
#
#                                             founders                                         industries employees   funding_raw  \
# 0     Christian Trummer, Eric Demuth, Paul Klanschek       Bitcoin, Blockchain, Cryptocurrency, FinTech   251-500  $283,013,472
# 1  Michael Hurnaus, Michael Lettner, Michael Tsch...                      GPS, Pet, Software, Wearables    51-100   $37,687,997
# 2       Felix Ohswald, Gregor Müller, Moritz Ohswald      Apps, Continuing Education, EdTech, Education   251-500  $100,662,844
# 3  Berend Snijder, Giulio Superti-Furga, Gregory ...  Biotechnology, Health Diagnostics, Machine Lea...     11-50    $6,000,000
# 4  Alexander Igelsböck, Andreas Glänzer, Martin B...  Advertising, Analytics, Artificial Intelligenc...   101-250   $46,298,685
#
#    funding_rounds  investors_count                                     investors_list                                source_url  \
# 0             5.0              6.0  ["DST Global", "Wintermute Trading", "Speedinv...  https://www.failory.com/startups/austria
# 1             5.0              5.0  ["['Guidepost Growth Equity'", "'Monkfish Equi...  https://www.failory.com/startups/austria
# 2             6.0              7.0  ["DN Capital", "Coatue", "Speedinvest", "Left ...  https://www.failory.com/startups/austria
# 3             2.0              5.0  ["42CAP", "Air Street Capital", "PUSH Ventures...  https://www.failory.com/startups/austria
# 4             4.0              7.0  ["Sapphire Ventures", "Speedinvest", "Felix Ca...  https://www.failory.com/startups/austria
#
#    employees_min  employees_max  funding_usd                                    industries_list  \
# 0          251.0          500.0  283013472.0  ["Bitcoin", "Blockchain", "Cryptocurrency", "F...
# 1           51.0          100.0   37687997.0            ["GPS", "Pet", "Software", "Wearables"]
# 2          251.0          500.0  100662844.0  ["Apps", "Continuing Education", "EdTech", "Ed...
# 3           11.0           50.0    6000000.0  ["Biotechnology", "Health Diagnostics", "Machi...
# 4          101.0          250.0   46298685.0  ["Advertising", "Analytics", "Artificial Intel...
#
#                                        founders_list
# 0  ["Christian Trummer", "Eric Demuth", "Paul Kla...
# 1  ["Michael Hurnaus", "Michael Lettner", "Michae...
# 2  ["Felix Ohswald", "Gregor M\u00c3\u00bcller", ...
# 3  ["Berend Snijder", "Giulio Superti-Furga", "Gr...
# 4  ["Alexander Igelsb\u00c3\u00b6ck", "Andreas Gl...
