# %% [markdown]
# ## OECD data on venture capital investments

# %%
import requests
import pandas as pd
from io import StringIO

# %%
# Define API query URL (CSV with labels format)
url = "https://sdmx.oecd.org/public/rest/data/OECD.SDD.TPS,DSD_VC@DF_VC_INV,1.0/...USD_EXC.A?startPeriod=2007&dimensionAtObservation=AllDimensions&format=csvfilewithlabels"

# Fetch data
response = requests.get(url)

# Load into pandas DataFrame
df = pd.read_csv(StringIO(response.text))

# Display first few rows
df.head()
# Out:
#   STRUCTURE                        STRUCTURE_ID  \
# 0  DATAFLOW  OECD.SDD.TPS:DSD_VC@DF_VC_INV(1.0)
# 1  DATAFLOW  OECD.SDD.TPS:DSD_VC@DF_VC_INV(1.0)
# 2  DATAFLOW  OECD.SDD.TPS:DSD_VC@DF_VC_INV(1.0)
# 3  DATAFLOW  OECD.SDD.TPS:DSD_VC@DF_VC_INV(1.0)
# 4  DATAFLOW  OECD.SDD.TPS:DSD_VC@DF_VC_INV(1.0)
#
#                                     STRUCTURE_NAME ACTION REF_AREA  \
# 0  Venture capital investments (market statistics)      I      BEL
# 1  Venture capital investments (market statistics)      I      CZE
# 2  Venture capital investments (market statistics)      I      CZE
# 3  Venture capital investments (market statistics)      I      CZE
# 4  Venture capital investments (market statistics)      I      CZE
#
#   Reference area     MEASURE                                          Measure  \
# 0        Belgium  VC_INV_MKT  Venture capital investments (market statistics)
# 1        Czechia  VC_INV_MKT  Venture capital investments (market statistics)
# 2        Czechia  VC_INV_MKT  Venture capital investments (market statistics)
# 3        Czechia  VC_INV_MKT  Venture capital investments (market statistics)
# 4        Czechia  VC_INV_MKT  Venture capital investments (market statistics)
#
#   BUSINESS_DEVELOPMENT_STAGE Business development stage  ... OBS_VALUE  \
# 0                       SEED                       Seed  ...       0.0
# 1                       SEED                       Seed  ...       0.0
# 2                       SEED                       Seed  ...       0.0
# 3                       SEED                       Seed  ...       0.0
# 4                       SEED                       Seed  ...       0.0
#
#   Observation value OBS_STATUS Observation status  UNIT_MULT  Unit multiplier  \
# 0               NaN          A       Normal value          6         Millions
# 1               NaN          A       Normal value          6         Millions
# 2               NaN          A       Normal value          6         Millions
# 3               NaN          A       Normal value          6         Millions
# 4               NaN          A       Normal value          6         Millions
#
#    CURRENCY   Currency DECIMALS Decimals
# 0       USD  US dollar        2      Two
# 1       USD  US dollar        2      Two
# 2       USD  US dollar        2      Two
# 3       USD  US dollar        2      Two
# 4       USD  US dollar        2      Two
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'STRUCTURE_NAME', 'ACTION', 'REF_AREA',
#        'Reference area', 'MEASURE', 'Measure', 'BUSINESS_DEVELOPMENT_STAGE',
#        'Business development stage', 'UNIT_MEASURE', 'Unit of measure', 'FREQ',
#        'Frequency of observation', 'TIME_PERIOD', 'Time period', 'OBS_VALUE',
#        'Observation value', 'OBS_STATUS', 'Observation status', 'UNIT_MULT',
#        'Unit multiplier', 'CURRENCY', 'Currency', 'DECIMALS', 'Decimals'],
#       dtype='object')

# %%
columns_to_retain = ["REF_AREA", "Reference area", "Business development stage","TIME_PERIOD", "UNIT_MULT", "CURRENCY", "OBS_VALUE"]

df = df[columns_to_retain]

# %%
df.sort_values(by=['REF_AREA', 'TIME_PERIOD'])
# Out:
#      REF_AREA Reference area      Business development stage  TIME_PERIOD  \
# 184       AUS      Australia  Start-up and other early stage         2007
# 185       AUS      Australia             Later stage venture         2007
# 186       AUS      Australia                           Total         2007
# 187       AUS      Australia                            Seed         2007
# 326       AUS      Australia                            Seed         2008
# ...       ...            ...                             ...          ...
# 1549      ZAF   South Africa                           Total         2019
# 1550      ZAF   South Africa                           Total         2020
# 1551      ZAF   South Africa                           Total         2021
# 1552      ZAF   South Africa                           Total         2022
# 1553      ZAF   South Africa                           Total         2023
#
#       UNIT_MULT CURRENCY   OBS_VALUE
# 184           6      USD   84.513701
# 185           6      USD  566.492828
# 186           6      USD  680.293455
# 187           6      USD   29.286926
# 326           6      USD   36.907230
# ...         ...      ...         ...
# 1549          6      USD  484.523132
# 1550          6      USD  109.346801
# 1551          6      USD   40.586963
# 1552          6      USD   67.211825
# 1553          6      USD   81.299410
#
# [2371 rows x 7 columns]

# %%
df["UNIT_MULT"].unique()
# Out:
# array([6])

# %%
df["CURRENCY"].unique()
# Out:
# array(['USD'], dtype=object)

# %% [markdown]
# !!! This means that all values are in millions of USD.

# %%
df["Reference area"].unique()
# Out:
# array(['Belgium', 'Czechia', 'Estonia', 'Greece', 'Hungary', 'Ireland',
#        'Latvia', 'Lithuania', 'Luxembourg', 'Poland', 'Slovak Republic',
#        'Slovenia', 'Bulgaria', 'Croatia', 'Romania', 'Portugal',
#        'Australia', 'Israel', 'Canada', 'United States', 'Russia',
#        'Austria', 'Denmark', 'Italy', 'Japan', 'Korea', 'New Zealand',
#        'United Kingdom', 'Finland', 'Netherlands', 'Norway',
#        'Switzerland', 'France', 'Germany', 'Spain', 'Sweden',
#        'South Africa'], dtype=object)

# %% [markdown]
# !!! 37 different countries:
#
# - 'Belgium', 'Czechia', 'Estonia',
# - 'Greece', 'Hungary', 'Ireland',
# - 'Latvia', 'Lithuania', 'Luxembourg',
# - 'Poland', 'Slovak Republic',
# - 'Slovenia', 'Bulgaria', 'Croatia',
# - 'Romania', 'Portugal', 'Australia',
# - 'Israel', 'Canada', 'United States',
# - 'Russia', 'Austria', 'Denmark',
# - 'Italy', 'Japan', 'Korea',
# - 'New Zealand', 'United Kingdom', 'Finland',
# - 'Netherlands', 'Norway', 'Switzerland',
# - 'France', 'Germany', 'Spain',
# - 'Sweden', 'South Africa'

# %%
df["Business development stage"].unique()
# Out:
# array(['Seed', 'Later stage venture', 'Start-up and other early stage',
#        'Total'], dtype=object)

# %% [markdown]
# The investemnts are differentiated into:
# - Seed
# - Start-up and other eraly stage
# - Later stage venture
# - Total

# %%
df["TIME_PERIOD"].unique()
# Out:
# array([2015, 2007, 2008, 2009, 2010, 2011, 2012, 2014, 2013, 2017, 2016,
#        2019, 2018, 2020, 2024, 2023, 2021, 2022])

# %% [markdown]
# !!! The time preiod id from 2015 to 2024, but not all countries have data for all years

# %% [markdown]
# Drop unit multiplier and currency as it is always millions of USD

# %%
df.drop([ "UNIT_MULT", "CURRENCY"], axis = 1, inplace= True)

# %%
df.sort_values(by=['REF_AREA', 'TIME_PERIOD'], inplace=True)

# %%
df
# Out:
#      REF_AREA Reference area      Business development stage  TIME_PERIOD  \
# 184       AUS      Australia  Start-up and other early stage         2007
# 185       AUS      Australia             Later stage venture         2007
# 186       AUS      Australia                           Total         2007
# 187       AUS      Australia                            Seed         2007
# 326       AUS      Australia                            Seed         2008
# ...       ...            ...                             ...          ...
# 1549      ZAF   South Africa                           Total         2019
# 1550      ZAF   South Africa                           Total         2020
# 1551      ZAF   South Africa                           Total         2021
# 1552      ZAF   South Africa                           Total         2022
# 1553      ZAF   South Africa                           Total         2023
#
#        OBS_VALUE
# 184    84.513701
# 185   566.492828
# 186   680.293455
# 187    29.286926
# 326    36.907230
# ...          ...
# 1549  484.523132
# 1550  109.346801
# 1551   40.586963
# 1552   67.211825
# 1553   81.299410
#
# [2371 rows x 5 columns]

# %%
df.to_csv("oecd_data.csv", index = False)
